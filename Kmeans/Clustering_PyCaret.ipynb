# %% [markdown]
# <a href="https://colab.research.google.com/github/antonionipo/Modelos-de-Clusterizacao-com-Python/blob/main/Kmeans/Clustering_PyCaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Last updated: 16 Feb 2023
#
# # 👋 PyCaret Clustering Tutorial
#
# PyCaret is an open-source, low-code machine learning library in Python that automates machine learning workflows. It is an end-to-end machine learning and model management tool that exponentially speeds up the experiment cycle and makes you more productive.
#
# Compared with the other open-source machine learning libraries, PyCaret is an alternate low-code library that can be used to replace hundreds of lines of code with a few lines only. This makes experiments exponentially fast and efficient. PyCaret is essentially a Python wrapper around several machine learning libraries and frameworks, such as scikit-learn, XGBoost, LightGBM, CatBoost, spaCy, Optuna, Hyperopt, Ray, and a few more.
#
# The design and simplicity of PyCaret are inspired by the emerging role of citizen data scientists, a term first used by Gartner. Citizen Data Scientists are power users who can perform both simple and moderately sophisticated analytical tasks that would previously have required more technical expertise.

# %% [markdown]
# # 💻 Installation
#
# PyCaret is tested and supported on the following 64-bit systems:
# - Python 3.7 – 3.10
# - Python 3.9 for Ubuntu only
# - Ubuntu 16.04 or later
# - Windows 7 or later
#
# You can install PyCaret with Python's pip package manager:
#
# `pip install pycaret`
#
# PyCaret's default installation will not install all the extra dependencies automatically. For that you will have to install the full version:
#
# `pip install pycaret[full]`
#
# or depending on your use-case you may install one of the following variant:
#
# - `pip install pycaret[analysis]`
# - `pip install pycaret[models]`
# - `pip install pycaret[tuner]`
# - `pip install pycaret[mlops]`
# - `pip install pycaret[parallel]`
# - `pip install pycaret[test]`

# %%
# !pip install pycaret[full]
# !pip install pycaret[analysis]
# !pip install pycaret[models]
# !pip install pycaret[tuner]
# !pip install pycaret[mlops]
# !pip install pycaret[parallel]
# !pip install pycaret[test]
# Out:
# Requirement already satisfied: pycaret[full] in /usr/local/lib/python3.11/dist-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (7.7.1)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (4.67.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2.1.4)
# Requirement already satisfied: jinja2>=3 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (3.1.5)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2.0.3)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.13.0)
# Requirement already satisfied: category-encoders>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (4.5.0)
# Requirement already satisfied: numba>=0.55.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.60.0)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (5.9.5)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2.1.5)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (8.6.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (5.10.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (3.1.1)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2.1.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.14.4)
# Requirement already satisfied: sktime==0.26.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2.0.4)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (3.1.1)
# Requirement already satisfied: shap~=0.44.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.44.1)
# Requirement already satisfied: interpret>=0.2.7 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.6.9)
# Requirement already satisfied: umap-learn>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.5.7)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (6.0.2)
# Requirement already satisfied: ydata-profiling>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (4.13.0)
# Requirement already satisfied: explainerdashboard>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.4.8)
# Requirement already satisfied: fairlearn==0.7.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.7.0)
# Requirement already satisfied: kmodes>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.12.2)
# Requirement already satisfied: mlxtend>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.23.4)
# Requirement already satisfied: statsforecast<1.6.0,>=0.5.5 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (1.5.0)
# Requirement already satisfied: hyperopt>=0.2.7 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.2.7)
# Requirement already satisfied: optuna>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (4.2.1)
# Requirement already satisfied: optuna-integration in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (4.2.1)
# Requirement already satisfied: scikit-optimize>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.10.2)
# Requirement already satisfied: mlflow>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2.20.3)
# Requirement already satisfied: gradio>=3.50.2 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (5.20.1)
# Requirement already satisfied: boto3>=1.24.56 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (1.37.9)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.115.11)
# Requirement already satisfied: uvicorn>=0.17.6 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.34.0)
# Requirement already satisfied: m2cgen>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.10.0)
# Requirement already satisfied: evidently~=0.4.16 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.4.40)
# Requirement already satisfied: dask>=2024.4.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2024.12.1)
# Requirement already satisfied: distributed>=2024.4.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2024.12.1)
# Requirement already satisfied: fugue~=0.8.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (0.8.7)
# Requirement already satisfied: flask in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2.3.3)
# Requirement already satisfied: Werkzeug<3.0,>=2.2 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2.3.8)
# Requirement already satisfied: pytest<8.0.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (7.4.4)
# Requirement already satisfied: moto<5.0.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (4.2.14)
# Requirement already satisfied: dash[testing] in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2.18.2)
# Requirement already satisfied: scikit-learn-intelex>=2023.0.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2025.2.0)
# Requirement already satisfied: catboost>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (1.2.7)
# Requirement already satisfied: xgboost>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[full]) (2.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from sktime==0.26.0->pycaret[full]) (24.2)
# Requirement already satisfied: scikit-base<0.8.0 in /usr/local/lib/python3.11/dist-packages (from sktime==0.26.0->pycaret[full]) (0.7.8)
# Requirement already satisfied: botocore<1.38.0,>=1.37.9 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.24.56->pycaret[full]) (1.37.9)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.24.56->pycaret[full]) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.24.56->pycaret[full]) (0.11.4)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost>=0.23.2->pycaret[full]) (0.20.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost>=0.23.2->pycaret[full]) (1.17.0)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from category-encoders>=2.4.0->pycaret[full]) (1.0.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2024.4.1->pycaret[full]) (8.1.8)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2024.4.1->pycaret[full]) (2024.10.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2024.4.1->pycaret[full]) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2024.4.1->pycaret[full]) (0.12.1)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.1->pycaret[full]) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.1->pycaret[full]) (1.1.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.1->pycaret[full]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.1->pycaret[full]) (3.0.0)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.1->pycaret[full]) (6.4.2)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.1->pycaret[full]) (1.26.20)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2024.4.1->pycaret[full]) (3.0.0)
# Requirement already satisfied: nltk>=3.6.7 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (3.9.1)
# Requirement already satisfied: pydantic>=1.10.13 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (2.10.6)
# Requirement already satisfied: litestar>=2.8.3 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (2.15.1)
# Requirement already satisfied: typing-inspect>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (0.9.0)
# Requirement already satisfied: watchdog>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (6.0.0)
# Requirement already satisfied: typer>=0.3 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (0.15.2)
# Requirement already satisfied: rich>=13 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (13.9.4)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (0.0.10)
# Requirement already satisfied: dynaconf>=3.2.4 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (3.2.10)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (2025.1.31)
# Requirement already satisfied: ujson>=5.4.0 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (5.10.0)
# Requirement already satisfied: uuid6>=2024.7.10 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (2024.7.10)
# Requirement already satisfied: cryptography>=43.0.1 in /usr/local/lib/python3.11/dist-packages (from evidently~=0.4.16->pycaret[full]) (43.0.3)
# Requirement already satisfied: dash-auth in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[full]) (2.3.0)
# Requirement already satisfied: dash-bootstrap-components>=1 in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[full]) (1.7.1)
# Requirement already satisfied: dtreeviz>=2.1 in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[full]) (2.2.2)
# Requirement already satisfied: flask_simplelogin in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[full]) (0.2.0)
# Requirement already satisfied: Flask-WTF>=1.1 in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[full]) (1.2.2)
# Requirement already satisfied: jupyter_dash>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[full]) (0.4.2)
# Requirement already satisfied: oyaml in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[full]) (1.0)
# Requirement already satisfied: waitress in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[full]) (3.0.2)
# Requirement already satisfied: triad>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from fugue~=0.8.0->pycaret[full]) (0.9.8)
# Requirement already satisfied: adagio>=0.2.4 in /usr/local/lib/python3.11/dist-packages (from fugue~=0.8.0->pycaret[full]) (0.2.6)
# Requirement already satisfied: qpd>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from fugue~=0.8.0->pycaret[full]) (0.4.4)
# Requirement already satisfied: fugue-sql-antlr>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from fugue~=0.8.0->pycaret[full]) (0.2.2)
# Requirement already satisfied: sqlglot in /usr/local/lib/python3.11/dist-packages (from fugue~=0.8.0->pycaret[full]) (25.6.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (3.7.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (0.5.0)
# Requirement already satisfied: gradio-client==1.7.2 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (1.7.2)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (0.28.1)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (3.10.15)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (11.1.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (0.9.10)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (0.46.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (0.13.2)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=3.50.2->pycaret[full]) (4.12.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.7.2->gradio>=3.50.2->pycaret[full]) (14.2)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.11/dist-packages (from hyperopt>=0.2.7->pycaret[full]) (3.4.2)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from hyperopt>=0.2.7->pycaret[full]) (1.0.0)
# Requirement already satisfied: py4j in /usr/local/lib/python3.11/dist-packages (from hyperopt>=0.2.7->pycaret[full]) (0.10.9.7)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn>=0.12.0->pycaret[full]) (0.1.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn>=0.12.0->pycaret[full]) (3.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=4.12.0->pycaret[full]) (3.21.0)
# Requirement already satisfied: interpret-core==0.6.9 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (0.6.9)
# Requirement already satisfied: ipykernel>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (6.17.1)
# Requirement already satisfied: SALib>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (1.5.1)
# Requirement already satisfied: dill>=0.2.5 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (0.3.9)
# Requirement already satisfied: aplr>=10.6.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (10.8.0)
# Requirement already satisfied: dash-core-components>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (2.0.0)
# Requirement already satisfied: dash-html-components>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (2.0.0)
# Requirement already satisfied: dash-table>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (5.0.0)
# Requirement already satisfied: dash-cytoscape>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (1.0.2)
# Requirement already satisfied: gevent>=1.3.6 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (24.11.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[full]) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[full]) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[full]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[full]) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[full]) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[full]) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[full]) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[full]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[full]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[full]) (4.9.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret[full]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret[full]) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret[full]) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[full]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[full]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[full]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[full]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[full]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[full]) (2.8.2)
# Requirement already satisfied: mlflow-skinny==2.20.3 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->pycaret[full]) (2.20.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->pycaret[full]) (1.15.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->pycaret[full]) (7.1.0)
# Requirement already satisfied: graphene<4 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->pycaret[full]) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->pycaret[full]) (23.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->pycaret[full]) (3.7)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->pycaret[full]) (18.1.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->pycaret[full]) (2.0.38)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (5.5.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (0.45.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (3.1.44)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (1.16.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (1.16.0)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (4.25.6)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (0.5.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from flask->pycaret[full]) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from flask->pycaret[full]) (1.9.0)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.11/dist-packages (from moto<5.0.0->pycaret[full]) (0.14.2)
# Requirement already satisfied: responses>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from moto<5.0.0->pycaret[full]) (0.25.6)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=4.2.0->pycaret[full]) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat>=4.2.0->pycaret[full]) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat>=4.2.0->pycaret[full]) (5.7.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.0->pycaret[full]) (0.43.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna>=3.0.0->pycaret[full]) (6.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.2.0->pycaret[full]) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.2.0->pycaret[full]) (2025.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.14.0->pycaret[full]) (9.0.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from plotly-resampler>=0.8.3.1->pycaret[full]) (0.1.4.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.11/dist-packages (from pmdarima>=2.0.4->pycaret[full]) (3.0.12)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest<8.0.0->pycaret[full]) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from pytest<8.0.0->pycaret[full]) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret[full]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret[full]) (3.10)
# Requirement already satisfied: daal==2025.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn-intelex>=2023.0.1->pycaret[full]) (2025.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from daal==2025.2.0->scikit-learn-intelex>=2023.0.1->pycaret[full]) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->daal==2025.2.0->scikit-learn-intelex>=2023.0.1->pycaret[full]) (1.2.0)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize>=0.9.0->pycaret[full]) (25.1.0)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.11/dist-packages (from shap~=0.44.0->pycaret[full]) (0.0.7)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.2->pycaret[full]) (0.5.13)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn>=0.17.6->pycaret[full]) (0.14.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost>=1.1.0->pycaret[full]) (2.21.5)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in /usr/local/lib/python3.11/dist-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling>=4.3.1->pycaret[full]) (0.7.6)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[full]) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[full]) (0.12.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[full]) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[full]) (1.12)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[full]) (4.4.2)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[full]) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[full]) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[full]) (1.9.2)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata-profiling>=4.3.1->pycaret[full]) (1.8.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (1.6.0)
# Requirement already satisfied: beautifulsoup4>=4.8.2 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (4.13.3)
# Requirement already satisfied: lxml>=4.6.2 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (5.3.1)
# Requirement already satisfied: percy>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (2.0.2)
# Requirement already satisfied: selenium<=4.2.0,>=3.141.0 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (4.2.0)
# Requirement already satisfied: multiprocess>=0.70.12 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (0.70.17)
# Requirement already satisfied: dash-testing-stub>=0.0.2 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "full"->pycaret[full]) (0.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic!=1.10.0,<2->mlflow>=2.0.0->pycaret[full]) (1.3.9)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio>=3.50.2->pycaret[full]) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.8.2->dash[testing]; extra == "full"->pycaret[full]) (2.6)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=43.0.1->evidently~=0.4.16->pycaret[full]) (1.17.1)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "full"->pycaret[full]) (1.1.21)
# Requirement already satisfied: colour in /usr/local/lib/python3.11/dist-packages (from dtreeviz>=2.1->explainerdashboard>=0.3.8->pycaret[full]) (0.1.5)
# Requirement already satisfied: wtforms in /usr/local/lib/python3.11/dist-packages (from Flask-WTF>=1.1->explainerdashboard>=0.3.8->pycaret[full]) (3.2.1)
# Requirement already satisfied: antlr4-python3-runtime<4.12 in /usr/local/lib/python3.11/dist-packages (from fugue-sql-antlr>=0.1.6->fugue~=0.8.0->pycaret[full]) (4.11.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /usr/local/lib/python3.11/dist-packages (from graphene<4->mlflow>=2.0.0->pycaret[full]) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /usr/local/lib/python3.11/dist-packages (from graphene<4->mlflow>=2.0.0->pycaret[full]) (3.2.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio>=3.50.2->pycaret[full]) (1.0.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio>=3.50.2->pycaret[full]) (3.17.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (6.1.12)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (24.0.1)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.11/dist-packages (from iterative-telemetry>=0.0.5->evidently~=0.4.16->pycaret[full]) (1.4.4)
# Requirement already satisfied: distro in /usr/local/lib/python3.11/dist-packages (from iterative-telemetry>=0.0.5->evidently~=0.4.16->pycaret[full]) (1.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.5.0->pycaret[full]) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (0.23.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret[full]) (4.3.6)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.11/dist-packages (from jupyter_dash>=0.4.1->explainerdashboard>=0.3.8->pycaret[full]) (1.9.2)
# Requirement already satisfied: litestar-htmx>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from litestar>=2.8.3->evidently~=0.4.16->pycaret[full]) (0.4.1)
# Requirement already satisfied: msgspec>=0.18.2 in /usr/local/lib/python3.11/dist-packages (from litestar>=2.8.3->evidently~=0.4.16->pycaret[full]) (0.19.0)
# Requirement already satisfied: multidict>=6.0.2 in /usr/local/lib/python3.11/dist-packages (from litestar>=2.8.3->evidently~=0.4.16->pycaret[full]) (6.1.0)
# Requirement already satisfied: multipart>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from litestar>=2.8.3->evidently~=0.4.16->pycaret[full]) (1.2.1)
# Requirement already satisfied: polyfactory>=2.6.3 in /usr/local/lib/python3.11/dist-packages (from litestar>=2.8.3->evidently~=0.4.16->pycaret[full]) (2.19.0)
# Requirement already satisfied: rich-click in /usr/local/lib/python3.11/dist-packages (from litestar>=2.8.3->evidently~=0.4.16->pycaret[full]) (1.8.6)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.6.7->evidently~=0.4.16->pycaret[full]) (2024.11.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.5.0->pycaret[full]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret[full]) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.10.13->evidently~=0.4.16->pycaret[full]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.10.13->evidently~=0.4.16->pycaret[full]) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13->evidently~=0.4.16->pycaret[full]) (3.0.0)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.11/dist-packages (from selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.11/dist-packages (from selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (0.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.0.0->pycaret[full]) (3.1.1)
# Requirement already satisfied: fs in /usr/local/lib/python3.11/dist-packages (from triad>=0.9.3->fugue~=0.8.0->pycaret[full]) (2.4.16)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.3->evidently~=0.4.16->pycaret[full]) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.9.0->evidently~=0.4.16->pycaret[full]) (1.0.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.22.0->evidently~=0.4.16->pycaret[full]) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.22.0->evidently~=0.4.16->pycaret[full]) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.22.0->evidently~=0.4.16->pycaret[full]) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.22.0->evidently~=0.4.16->pycaret[full]) (1.0.4)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (6.5.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=43.0.1->evidently~=0.4.16->pycaret[full]) (2.22)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.11/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (2.38.0)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (5.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret>=0.2.7->pycaret[full]) (7.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (4.0.12)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13->evidently~=0.4.16->pycaret[full]) (0.1.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (23.1.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (1.2.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.37b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (0.37b0)
# Requirement already satisfied: faker in /usr/local/lib/python3.11/dist-packages (from polyfactory>=2.6.3->litestar>=2.8.3->evidently~=0.4.16->pycaret[full]) (37.0.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.9->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (1.2.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in /usr/local/lib/python3.11/dist-packages (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (24.2.1)
# Requirement already satisfied: urllib3-secure-extra in /usr/local/lib/python3.11/dist-packages (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (0.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "full"->pycaret[full]) (1.7.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (4.9)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.2.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (1.5.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (1.24.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow>=2.0.0->pycaret[full]) (0.6.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (1.8.0)
# Requirement already satisfied: pycaret[analysis] in /usr/local/lib/python3.11/dist-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (7.7.1)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (4.67.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (2.1.4)
# Requirement already satisfied: jinja2>=3 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (3.1.5)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (2.0.3)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (0.13.0)
# Requirement already satisfied: category-encoders>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (4.5.0)
# ...
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret[test]) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret[test]) (2025.1.31)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (2.3.3)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (4.12.2)
# Requirement already satisfied: retrying in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (1.6.0)
# Requirement already satisfied: beautifulsoup4>=4.8.2 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (4.13.3)
# Requirement already satisfied: lxml>=4.6.2 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (5.3.1)
# Requirement already satisfied: percy>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (2.0.2)
# Requirement already satisfied: selenium<=4.2.0,>=3.141.0 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (4.2.0)
# Requirement already satisfied: waitress>=1.4.4 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (3.0.2)
# Requirement already satisfied: multiprocess>=0.70.12 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (0.70.17)
# Requirement already satisfied: dash-testing-stub>=0.0.2 in /usr/local/lib/python3.11/dist-packages (from dash[testing]; extra == "test"->pycaret[test]) (0.0.2)
# Requirement already satisfied: triad>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from fugue[dask]; extra == "test"->pycaret[test]) (0.9.8)
# Requirement already satisfied: adagio>=0.2.4 in /usr/local/lib/python3.11/dist-packages (from fugue[dask]; extra == "test"->pycaret[test]) (0.2.6)
# Requirement already satisfied: qpd>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from fugue[dask]; extra == "test"->pycaret[test]) (0.4.4)
# Requirement already satisfied: fugue-sql-antlr>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from fugue[dask]; extra == "test"->pycaret[test]) (0.2.2)
# Requirement already satisfied: sqlglot in /usr/local/lib/python3.11/dist-packages (from fugue[dask]; extra == "test"->pycaret[test]) (25.6.1)
# Requirement already satisfied: dask>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (2024.12.1)
# Requirement already satisfied: pyarrow>=7.0.0 in /usr/local/lib/python3.11/dist-packages (from fugue[dask]; extra == "test"->pycaret[test]) (18.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.8.2->dash[testing]; extra == "test"->pycaret[test]) (2.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.9.201->moto<5.0.0->pycaret[test]) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.9.201->moto<5.0.0->pycaret[test]) (0.11.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.3.1->moto<5.0.0->pycaret[test]) (1.17.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2023.5.0->dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (8.1.8)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2023.5.0->dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (2024.10.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2023.5.0->dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2023.5.0->dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2023.5.0->dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (0.12.1)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (1.1.21)
# Requirement already satisfied: distributed==2024.12.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (2024.12.1)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from distributed==2024.12.1->dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from distributed==2024.12.1->dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (1.1.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.11/dist-packages (from distributed==2024.12.1->dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from distributed==2024.12.1->dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (3.0.0)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from distributed==2024.12.1->dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (6.4.2)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from distributed==2024.12.1->dask[dataframe,distributed]>=2023.5.0; extra == "dask"->fugue[dask]; extra == "test"->pycaret[test]) (3.0.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash[testing]; extra == "test"->pycaret[test]) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash[testing]; extra == "test"->pycaret[test]) (1.9.0)
# Requirement already satisfied: antlr4-python3-runtime<4.12 in /usr/local/lib/python3.11/dist-packages (from fugue-sql-antlr>=0.1.6->fugue[dask]; extra == "test"->pycaret[test]) (4.11.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[test]) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[test]) (6.1.12)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret[test]) (24.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.5.0->pycaret[test]) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[test]) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[test]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[test]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[test]) (0.23.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret[test]) (4.3.6)
# Requirement already satisfied: dill>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from multiprocess>=0.70.12->dash[testing]; extra == "test"->pycaret[test]) (0.3.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.5.0->pycaret[test]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret[test]) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret[test]) (1.17.0)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.11/dist-packages (from selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "test"->pycaret[test]) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.11/dist-packages (from selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "test"->pycaret[test]) (0.12.2)
# Requirement already satisfied: fs in /usr/local/lib/python3.11/dist-packages (from triad>=0.9.3->fugue[dask]; extra == "test"->pycaret[test]) (2.4.16)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (6.5.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.3.1->moto<5.0.0->pycaret[test]) (2.22)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (23.1.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (1.2.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "test"->pycaret[test]) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "test"->pycaret[test]) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.9->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "test"->pycaret[test]) (1.2.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in /usr/local/lib/python3.11/dist-packages (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "test"->pycaret[test]) (24.2.1)
# Requirement already satisfied: urllib3-secure-extra in /usr/local/lib/python3.11/dist-packages (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "test"->pycaret[test]) (0.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "test"->pycaret[test]) (1.7.1)
# Requirement already satisfied: appdirs~=1.4.3 in /usr/local/lib/python3.11/dist-packages (from fs->triad>=0.9.3->fugue[dask]; extra == "test"->pycaret[test]) (1.4.4)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (0.2.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (1.5.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<=4.2.0,>=3.141.0->dash[testing]; extra == "test"->pycaret[test]) (0.14.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (1.24.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[test]) (1.8.0)

# %%
# check installed version
import pycaret
pycaret.__version__
# Out:
# '3.3.2'

# %% [markdown]
# # 🚀 Quick start

# %% [markdown]
# PyCaret's Clustering Module is an unsupervised machine learning module that performs the task of grouping a set of objects in such a way that objects in the same group (also known as a cluster) are more similar to each other than to those in other groups.
#
# It provides several pre-processing features that prepare the data for modeling through the setup function. It has over 10 ready-to-use algorithms and several plots to analyze the performance of trained models.
#
# A typical workflow in PyCaret's unsupervised module consist of following 6 steps in this order:
#
# ### **Setup** ➡️ **Create Model** ➡️ **Assign Labels** ➡️ **Analyze Model** ➡️ **Prediction** ➡️ **Save Model**

# %%
# loading sample dataset from pycaret dataset module
from pycaret.datasets import get_data
data = get_data('jewellery')
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %% [markdown]
# ## Setup
# This function initializes the training environment and creates the transformation pipeline. Setup function must be called before executing any other function in PyCaret. It only has one required parameter i.e. `data`. All the other parameters are optional.

# %%
# import pycaret clustering and init setup
from pycaret.clustering import *
s = setup(data, session_id = 123)
# Out:
# <style type="text/css">
# #T_f692c_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f692c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f692c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f692c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f692c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f692c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f692c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f692c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f692c_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_f692c_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_f692c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f692c_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_f692c_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_f692c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f692c_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_f692c_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_f692c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f692c_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_f692c_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f692c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f692c_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_f692c_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f692c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f692c_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_f692c_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f692c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f692c_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_f692c_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f692c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f692c_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_f692c_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f692c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f692c_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_f692c_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f692c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f692c_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_f692c_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f692c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f692c_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_f692c_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f692c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f692c_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_f692c_row12_col1" class="data row12 col1" >ca83</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Once the setup has been successfully executed it shows the information grid containing experiment level information.
#
# - **Session id:**  A pseudo-random number distributed as a seed in all functions for later reproducibility. If no `session_id` is passed, a random number is automatically generated that is distributed to all functions.<br/>
# <br/>
# - **Original data shape:**  Shape of the original data prior to any transformations. <br/>
# <br/>
# - **Transformed data shape:**  Shape of data after transformations <br/>
# <br/>
# - **Numeric features :**  The number of features considered as numerical. <br/>
# <br/>
# - **Categorical features :**  The number of features considered as categorical. <br/>

# %% [markdown]
# PyCaret has two set of API's that you can work with. (1) Functional (as seen above) and (2) Object Oriented API.
#
# With Object Oriented API instead of executing functions directly you will import a class and execute methods of class.

# %%
# import ClusteringExperiment and init the class
from pycaret.clustering import ClusteringExperiment
exp = ClusteringExperiment()

# %%
# check the type of exp
type(exp)
# Out:
# pycaret.clustering.oop.ClusteringExperiment

# %%
# init setup on exp
exp.setup(data, session_id = 123)
# Out:
# <style type="text/css">
# #T_1c5c5_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1c5c5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c5c5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1c5c5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c5c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1c5c5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1c5c5_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1c5c5_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_1c5c5_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1c5c5_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_1c5c5_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1c5c5_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_1c5c5_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1c5c5_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_1c5c5_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1c5c5_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_1c5c5_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1c5c5_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_1c5c5_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1c5c5_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_1c5c5_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1c5c5_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_1c5c5_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1c5c5_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_1c5c5_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1c5c5_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_1c5c5_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1c5c5_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_1c5c5_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1c5c5_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_1c5c5_row12_col1" class="data row12 col1" >6ab9</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# You can use any of the two method i.e. Functional or OOP and even switch back and forth between two set of API's. The choice of method will not impact the results and has been tested for consistency.
# ___

# %% [markdown]
# ## Create Model
#
# This function trains and evaluates the performance of a given model. Metrics evaluated can be accessed using the `get_metrics` function. Custom metrics can be added or removed using the `add_metric` and `remove_metric` function. All the available models can be accessed using the `models` function.

# %%
# train kmeans model
kmeans = create_model('kmeans')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c2a58" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2a58_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c2a58_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c2a58_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c2a58_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c2a58_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c2a58_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2a58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2a58_row0_col0" class="data row0 col0" >0.7207</td>
#       <td id="T_c2a58_row0_col1" class="data row0 col1" >5011.8115</td>
#       <td id="T_c2a58_row0_col2" class="data row0 col2" >0.4114</td>
#       <td id="T_c2a58_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c2a58_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c2a58_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# to check all the available models
models()
# Out:
#                                        Name  \
# ID
# kmeans                   K-Means Clustering
# ap                     Affinity Propagation
# meanshift             Mean Shift Clustering
# sc                      Spectral Clustering
# hclust             Agglomerative Clustering
# dbscan     Density-Based Spatial Clustering
# optics                    OPTICS Clustering
# birch                      Birch Clustering
# kmodes                   K-Modes Clustering
#
#                                                    Reference
# ID
# kmeans                        sklearn.cluster._kmeans.KMeans
# ap         sklearn.cluster._affinity_propagation.Affinity...
# meanshift              sklearn.cluster._mean_shift.MeanShift
# sc              sklearn.cluster._spectral.SpectralClustering
# hclust     sklearn.cluster._agglomerative.AgglomerativeCl...
# dbscan                        sklearn.cluster._dbscan.DBSCAN
# optics                        sklearn.cluster._optics.OPTICS
# birch                           sklearn.cluster._birch.Birch
# kmodes                                  kmodes.kmodes.KModes

# %%
# train meanshift model
meanshift = create_model('meanshift')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d1da3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1da3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d1da3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d1da3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d1da3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d1da3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d1da3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1da3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d1da3_row0_col0" class="data row0 col0" >0.7393</td>
#       <td id="T_d1da3_row0_col1" class="data row0 col1" >3567.5370</td>
#       <td id="T_d1da3_row0_col2" class="data row0 col2" >0.3435</td>
#       <td id="T_d1da3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d1da3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d1da3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ## Assign Model
# This function assigns cluster labels to the training data, given a trained model.

# %%
kmeans_cluster = assign_model(kmeans)
kmeans_cluster
# Out:
#      Age  Income  SpendingScore       Savings    Cluster
# 0     58   77769       0.791329   6559.830078  Cluster 2
# 1     59   81799       0.791082   5417.661621  Cluster 2
# 2     62   74751       0.702657   9258.993164  Cluster 2
# 3     59   74373       0.765680   7346.334473  Cluster 2
# 4     87   17760       0.348778  16869.507812  Cluster 1
# ..   ...     ...            ...           ...        ...
# 500   28  101206       0.387441  14936.775391  Cluster 3
# 501   93   19934       0.203140  17969.693359  Cluster 1
# 502   90   35297       0.355149  16091.402344  Cluster 1
# 503   91   20681       0.354679  18401.087891  Cluster 1
# 504   89   30267       0.289310  14386.351562  Cluster 1
#
# [505 rows x 5 columns]

# %% [markdown]
# ## Analyze Model

# %% [markdown]
# You can use the `plot_model` function to analyzes the performance of a trained model on the test set. It may require re-training the model in certain cases.

# %%
# plot pca cluster plot
plot_model(kmeans, plot = 'cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6b1dbf4b-8700-46e4-9377-46067f6fe75f" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b1dbf4b-8700-46e4-9377-46067f6fe75f")) {                    Plotly.newPlot(                        "6b1dbf4b-8700-46e4-9377-46067f6fe75f",                        [{"customdata":[[26],[17],[20],[24],[24],[17],[29],[27],[93],[17],[24],[86],[28],[23],[28],[18],[23],[29],[23],[32],[28],[24],[25],[91],[28],[87],[82],[24],[20],[82],[25],[22],[28],[27],[21],[26],[21],[27],[31],[23],[24],[77],[86],[34],[88],[25],[26],[18],[83],[29],[26],[28],[26],[90],[17],[30],[22],[89],[83],[84],[22],[88],[83],[90],[25],[24],[20],[85],[25],[29],[25],[92]],"hovertemplate":"Cluster=Cluster 0\u003cbr\u003ePCA1=%{x}\u003cbr\u003ePCA2=%{y}\u003cbr\u003eFeature=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cluster 0","marker":{"color":"#636efa","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"Cluster 0","orientation":"v","showlegend":true,"x":[51532.470054685786,61085.161818166234,47415.3891559652,45280.29646688088,53976.78999307675,59803.045575974975,47210.61128826446,47518.881323479785,50874.59371963914,48697.32854572941,59239.8535212259,52679.13743936507,52465.033585302095,51395.2243558633,48029.23597884719,48551.897789887546,54778.919906972726,43600.216207210506,63317.066530294185,41328.252680468315,48281.964760281175,61617.25601853893,55783.428854090234,43084.4313185626,46000.8024834085,41859.15436607785,50433.85140507416,52263.49411048378,54230.311428764566,45920.30382555986,45728.401139272224,45302.57091364991,41933.87633764401,46271.74997443963,54542.56027032768,50397.083884591375,48602.57110350955,49923.23240059172,47836.44838887485,45049.71302323946,55795.99791010047,52844.21452066905,48577.245951971614,44074.74433395841,47964.55228506111,62912.45710039265,52086.380659501905,55587.35172793506,42157.805430948756,66750.62107639125,56651.455486319515,53924.59704186732,47842.883669132316,48410.009288958136,59798.174818909996,47549.76255316081,57857.289053149805,43861.74707161998,43629.0127400591,46993.64107086381,58984.55028389008,44952.90204718011,41580.27174136409,42045.79572232816,55809.6082475434,59196.59307835406,53899.23405406334,42414.13983525131,53422.552479964776,56449.678132767534,55168.45153662265,47182.06860121162],"xaxis":"x","y":[6006.733800938243,4243.721803980181,4709.388721993279,4437.356755042896,5488.389848804965,8450.307548937868,6674.234783135654,4941.999476017806,-5178.053057007979,5282.4978616551825,4745.14449328446,-4749.056737128208,3371.533064192322,5657.241523409536,5422.3237152636475,4668.214701347183,4629.791345722701,-5657.478374018929,4946.177503380891,-4823.645609095864,8499.966919747447,6726.313729421174,4732.08767470549,-4660.855325409072,3884.452852169688,-4543.326342656851,-6854.205790290373,5916.358116348496,3238.4289374841264,-4953.921494062037,3658.3064353496716,3778.1816093851326,4717.997031231377,4207.414538362315,4193.883189681694,2890.550760271959,6249.537248101819,6048.724076369267,6059.983303443475,4590.872356292775,4252.897482631877,-5677.667836398266,-6305.307643166656,-6307.668957592928,-4397.185708241038,5261.355290099561,3388.4270675204825,3427.1351701713465,-5954.454575332944,2693.0080673251973,4271.292256835255,5765.842917677416,4758.188583448418,-5693.665477980666,4315.751653167788,3437.8966252972823,5717.501103769999,-6877.036237163756,-6254.840940318073,-4647.129392602885,3350.711797535984,-4985.514604349097,-5615.560841025165,-3106.1031340528148,3879.149542578088,3903.974813791066,3176.746804746795,-5432.2819843403295,3894.2354040686,5101.398631128977,4016.9815008394594,-4557.716265875773],"yaxis":"y","type":"scatter","textposition":"top center"},{"customdata":[[88] ...

# %%
# plot elbow
plot_model(kmeans, plot = 'elbow')

# %%
# plot silhouette
plot_model(kmeans, plot = 'silhouette')

# %%
# check docstring to see available plots
# help(plot_model)

# %% [markdown]
# An alternate to `plot_model` function is `evaluate_model`. It can only be used in Notebook since it uses ipywidget.

# %%
evaluate_model(kmeans)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ## Prediction
# The `predict_model` function returns `Cluster` label as a new column in the input dataframe. This step may or may not be needed depending on the use-case. Some times clustering models are trained for analysis purpose only and the interest of user is only in assigned labels on the training dataset, that can be done using `assign_model` function. `predict_model` is only useful when you want to obtain cluster labels on unseen data (i.e. data that was not used during training the model).

# %%
# predict on test set
kmeans_pred = predict_model(kmeans, data=data)
kmeans_pred
# Out:
#       Age    Income  SpendingScore       Savings    Cluster
# 0    58.0   77769.0       0.791329   6559.829923  Cluster 2
# 1    59.0   81799.0       0.791082   5417.661426  Cluster 2
# 2    62.0   74751.0       0.702657   9258.992965  Cluster 2
# 3    59.0   74373.0       0.765680   7346.334504  Cluster 2
# 4    87.0   17760.0       0.348778  16869.507130  Cluster 1
# ..    ...       ...            ...           ...        ...
# 500  28.0  101206.0       0.387441  14936.775389  Cluster 3
# 501  93.0   19934.0       0.203140  17969.693769  Cluster 1
# 502  90.0   35297.0       0.355149  16091.401954  Cluster 1
# 503  91.0   20681.0       0.354679  18401.088445  Cluster 1
# 504  89.0   30267.0       0.289310  14386.351880  Cluster 1
#
# [505 rows x 5 columns]

# %% [markdown]
# ## Save Model

# %% [markdown]
# Finally, you can save the entire pipeline on disk for later use, using pycaret's `save_model` function.

# %%
# save pipeline
save_model(kmeans, 'kmeans_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Age', 'Income', 'SpendingScore',
#                                               'Savings'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('trained_model', KMeans(n_clusters=4, random_state=123))]),
#  'kmeans_pipeline.pkl')

# %%
# load pipeline
kmeans_pipeline = load_model('kmeans_pipeline')
kmeans_pipeline
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Age', 'Income', 'SpendingScore',
#                                              'Savings'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('trained_model', KMeans(n_clusters=4, random_state=123))])

# %% [markdown]
# # 👇 Detailed function-by-function overview

# %% [markdown]
# ## ✅ Setup
# This function initializes the training environment and creates the transformation pipeline. Setup function must be called before executing any other function in PyCaret. It only has one required parameter i.e. `data`. All the other parameters are optional.

# %%
# init setup
s = setup(data, session_id = 123)
# Out:
# <style type="text/css">
# #T_4bf5a_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4bf5a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bf5a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4bf5a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bf5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4bf5a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4bf5a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4bf5a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4bf5a_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_4bf5a_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_4bf5a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4bf5a_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_4bf5a_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_4bf5a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4bf5a_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_4bf5a_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_4bf5a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4bf5a_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_4bf5a_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4bf5a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4bf5a_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_4bf5a_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4bf5a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4bf5a_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_4bf5a_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4bf5a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4bf5a_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_4bf5a_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4bf5a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4bf5a_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_4bf5a_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4bf5a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4bf5a_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_4bf5a_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4bf5a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4bf5a_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_4bf5a_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4bf5a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4bf5a_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_4bf5a_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4bf5a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4bf5a_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_4bf5a_row12_col1" class="data row12 col1" >aa28</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# To access all the variables created by the setup function such as transformed dataset, random_state, etc. you can use `get_config` method.

# %%
# check all available config
get_config()
# Out:
# {'USI',
#  'X',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_available_plots',
#  '_ml_usecase',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'exp_id',
#  'exp_name_log',
#  'gpu_n_jobs_param',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'is_multiclass',
#  'log_plots_param',
#  'logging_param',
#  'memory',
#  'n_jobs_param',
#  'pipeline',
#  'seed',
#  'train',
#  'train_transformed',
#  'variable_and_property_keys',
#  'variables'}

# %%
# lets access X_train_transformed
get_config('X_train_transformed')
# Out:
#       Age    Income  SpendingScore       Savings
# 0    58.0   77769.0       0.791329   6559.830078
# 1    59.0   81799.0       0.791082   5417.661621
# 2    62.0   74751.0       0.702657   9258.993164
# 3    59.0   74373.0       0.765680   7346.334473
# 4    87.0   17760.0       0.348778  16869.507812
# ..    ...       ...            ...           ...
# 500  28.0  101206.0       0.387441  14936.775391
# 501  93.0   19934.0       0.203140  17969.693359
# 502  90.0   35297.0       0.355149  16091.402344
# 503  91.0   20681.0       0.354679  18401.087891
# 504  89.0   30267.0       0.289310  14386.351562
#
# [505 rows x 4 columns]

# %%
# another example: let's access seed
print("The current seed is: {}".format(get_config('seed')))

# now lets change it using set_config
set_config('seed', 786)
print("The new seed is: {}".format(get_config('seed')))
# Out:
# The current seed is: 123
# The new seed is: 786

# %% [markdown]
# All the preprocessing configurations and experiment settings/parameters are passed into the `setup` function. To see all available parameters, check the docstring:

# %%
# help(setup)

# %%
# init setup with normalize = True

s = setup(data, session_id = 123,
          normalize = True, normalize_method = 'minmax')
# Out:
# <style type="text/css">
# #T_a945d_row4_col1, #T_a945d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a945d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a945d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a945d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a945d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a945d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a945d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a945d_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_a945d_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a945d_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_a945d_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a945d_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_a945d_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a945d_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_a945d_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a945d_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_a945d_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a945d_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_a945d_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a945d_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_a945d_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a945d_row8_col0" class="data row8 col0" >Normalize</td>
#       <td id="T_a945d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a945d_row9_col0" class="data row9 col0" >Normalize method</td>
#       <td id="T_a945d_row9_col1" class="data row9 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a945d_row10_col0" class="data row10 col0" >CPU Jobs</td>
#       <td id="T_a945d_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a945d_row11_col0" class="data row11 col0" >Use GPU</td>
#       <td id="T_a945d_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a945d_row12_col0" class="data row12 col0" >Log Experiment</td>
#       <td id="T_a945d_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a945d_row13_col0" class="data row13 col0" >Experiment Name</td>
#       <td id="T_a945d_row13_col1" class="data row13 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a945d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a945d_row14_col0" class="data row14 col0" >USI</td>
#       <td id="T_a945d_row14_col1" class="data row14 col1" >df86</td>
#     </tr>
#   </tbody>
# </table>

# %%
# lets check the X_train_transformed to see effect of params passed
get_config('X_train_transformed')['Age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Notice that all the values are between 0 and 1 - that is because we passed `normalize=True` in the `setup` function. If you don't remember how it compares to actual data, no problem - we can also access non-transformed values using `get_config` and then compare. See below and notice the range of values on x-axis and compare it with histogram above.

# %%
get_config('X_train')['Age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## ✅ Experiment Logging
# PyCaret integrates with many different type of experiment loggers (default = 'mlflow'). To turn on experiment tracking in PyCaret you can set `log_experiment` and `experiment_name` parameter. It will automatically track all the metrics, hyperparameters, and artifacts based on the defined logger.

# %%
# from pycaret.clustering import *
# s = setup(data, log_experiment='mlflow', experiment_name='jewellery_project')

# %%
# train kmeans
# kmeans = create_model('kmeans')

# %%
# start mlflow server on localhost:5000
# !mlflow ui

# %% [markdown]
# By default PyCaret uses `MLFlow` logger that can be changed using `log_experiment` parameter. Following loggers are available:
#
#     - mlflow
#     - wandb
#     - comet_ml
#     - dagshub
#
# Other logging related parameters that you may find useful are:
#
# - experiment_custom_tags
# - log_plots
# - log_data
# - log_profile
#
# For more information check out the docstring of the `setup` function.

# %%
# help(setup)

# %% [markdown]
# ## ✅ Create Model
# This function trains and evaluates the performance of a given estimator using cross-validation. The output of this function is a scoring grid with CV scores by fold. Metrics evaluated during CV can be accessed using the `get_metrics` function. Custom metrics can be added or removed using `add_metric` and `remove_metric` function. All the available models can be accessed using the models function.

# %%
# check all the available models
models()
# Out:
#                                        Name  \
# ID
# kmeans                   K-Means Clustering
# ap                     Affinity Propagation
# meanshift             Mean Shift Clustering
# sc                      Spectral Clustering
# hclust             Agglomerative Clustering
# dbscan     Density-Based Spatial Clustering
# optics                    OPTICS Clustering
# birch                      Birch Clustering
# kmodes                   K-Modes Clustering
#
#                                                    Reference
# ID
# kmeans                        sklearn.cluster._kmeans.KMeans
# ap         sklearn.cluster._affinity_propagation.Affinity...
# meanshift              sklearn.cluster._mean_shift.MeanShift
# sc              sklearn.cluster._spectral.SpectralClustering
# hclust     sklearn.cluster._agglomerative.AgglomerativeCl...
# dbscan                        sklearn.cluster._dbscan.DBSCAN
# optics                        sklearn.cluster._optics.OPTICS
# birch                           sklearn.cluster._birch.Birch
# kmodes                                  kmodes.kmodes.KModes

# %%
# train kmeans
kmeans = create_model('kmeans')
# Out:
# <style type="text/css">
# </style>
# <table id="T_65903" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65903_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_65903_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_65903_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_65903_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_65903_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_65903_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65903_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65903_row0_col0" class="data row0 col0" >0.7274</td>
#       <td id="T_65903_row0_col1" class="data row0 col1" >1045.9028</td>
#       <td id="T_65903_row0_col2" class="data row0 col2" >0.4191</td>
#       <td id="T_65903_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_65903_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_65903_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# The function above has return trained model object as an output. The scoring grid is only displayed and not returned. If you need access to the scoring grid you can use `pull` function to access the dataframe.

# %%
kmeans_results = pull()
print(type(kmeans_results))
kmeans_results
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Silhouette  Calinski-Harabasz  Davies-Bouldin  Homogeneity  Rand Index  \
# 0      0.7274          1045.9028          0.4191            0           0
#
#    Completeness
# 0             0

# %%
# train kmeans with 10 clusters
create_model('kmeans', num_clusters = 10)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f82c0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f82c0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f82c0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f82c0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f82c0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f82c0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f82c0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f82c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f82c0_row0_col0" class="data row0 col0" >0.2224</td>
#       <td id="T_f82c0_row0_col1" class="data row0 col1" >2174.5428</td>
#       <td id="T_f82c0_row0_col2" class="data row0 col2" >1.5598</td>
#       <td id="T_f82c0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f82c0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f82c0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# KMeans(n_clusters=10, random_state=123)

# %% [markdown]
# Some other parameters that you might find very useful in `create_model` are:
#
# - num_clusters
# - ground_truth
# - fit_kwargs
# - experiment_custom_tags
# - engine
#
# You can check the docstring of the function for more info.

# %%
# help(create_model)

# %% [markdown]
# ## ✅ Assign Model
# This function assigns cluster labels to the training data, given a trained model.

# %%
assign_model(kmeans)
# Out:
#      Age  Income  SpendingScore       Savings    Cluster
# 0     58   77769       0.791329   6559.830078  Cluster 1
# 1     59   81799       0.791082   5417.661621  Cluster 1
# 2     62   74751       0.702657   9258.993164  Cluster 1
# 3     59   74373       0.765680   7346.334473  Cluster 1
# 4     87   17760       0.348778  16869.507812  Cluster 2
# ..   ...     ...            ...           ...        ...
# 500   28  101206       0.387441  14936.775391  Cluster 3
# 501   93   19934       0.203140  17969.693359  Cluster 2
# 502   90   35297       0.355149  16091.402344  Cluster 2
# 503   91   20681       0.354679  18401.087891  Cluster 2
# 504   89   30267       0.289310  14386.351562  Cluster 2
#
# [505 rows x 5 columns]

# %% [markdown]
# ## ✅ Plot Model
# This function analyzes the performance of a trained model.

# %%
# to control the scale of plot
plot_model(kmeans, plot = 'elbow', scale = 2)

# %%
# to save the plot
plot_model(kmeans, plot = 'elbow', save=True)
# Out:
# 'Elbow Plot.png'

# %% [markdown]
# Some other parameters that you might find very useful in `plot_model` are:
#
# - feature
# - label
# - display_format
#
# You can check the docstring of the function for more info.

# %%
# help(plot_model)

# %% [markdown]
# ## ✅ Deploy Model
# This function deploys the entire ML pipeline on the cloud.
#
# **AWS:**  When deploying model on AWS S3, environment variables must be configured using the command-line interface. To configure AWS environment variables, type `aws configure` in terminal. The following information is required which can be generated using the Identity and Access Management (IAM) portal of your amazon console account:
#
# - AWS Access Key ID
# - AWS Secret Key Access
# - Default Region Name (can be seen under Global settings on your AWS console)
# - Default output format (must be left blank)
#
# **GCP:** To deploy a model on Google Cloud Platform ('gcp'), the project must be created using the command-line or GCP console. Once the project is created, you must create a service account and download the service account key as a JSON file to set environment variables in your local environment. Learn more about it: https://cloud.google.com/docs/authentication/production
#
# **Azure:** To deploy a model on Microsoft Azure ('azure'), environment variables for the connection string must be set in your local environment. Go to settings of storage account on Azure portal to access the connection string required.
# AZURE_STORAGE_CONNECTION_STRING (required as environment variable)
# Learn more about it: https://docs.microsoft.com/en-us/azure/storage/blobs/storage-quickstart-blobs-python?toc=%2Fpython%2Fazure%2FTOC.json

# %%
# deploy model on aws s3
# deploy_model(kmeans, model_name = 'my_first_platform_on_aws',
#             platform = 'aws', authentication = {'bucket' : 'pycaret-test'})

# %%
# load model from aws s3
# loaded_from_aws = load_model(model_name = 'my_first_platform_on_aws', platform = 'aws',
#                              authentication = {'bucket' : 'pycaret-test'})

# loaded_from_aws

# %% [markdown]
# ## ✅ Save / Load Model
# This function saves the transformation pipeline and a trained model object into the current working directory as a pickle file for later use.

# %%
# save model
save_model(kmeans, 'my_first_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Age', 'Income', 'SpendingScore',
#                                               'Savings'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('normalize', TransformerWrapper(transformer=MinMaxScaler())),
#                  ('trained_model', KMeans(n_clusters=4, random_state=123))]),
#  'my_first_model.pkl')

# %%
# load model
loaded_from_disk = load_model('my_first_model')
loaded_from_disk
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Age', 'Income', 'SpendingScore',
#                                              'Savings'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('normalize', TransformerWrapper(transformer=MinMaxScaler())),
#                 ('trained_model', KMeans(n_clusters=4, random_state=123))])

# %% [markdown]
# ## ✅ Save / Load Experiment
# This function saves all the experiment variables on disk, allowing to later resume without rerunning the setup function.

# %%
# save experiment
save_experiment('my_experiment')

# %%
# load experiment from disk
exp_from_disk = load_experiment('my_experiment', data=data)
# Out:
# <style type="text/css">
# #T_23ea2_row4_col1, #T_23ea2_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_23ea2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23ea2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_23ea2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23ea2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23ea2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_23ea2_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_23ea2_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_23ea2_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_23ea2_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_23ea2_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_23ea2_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_23ea2_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_23ea2_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_23ea2_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_23ea2_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_23ea2_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_23ea2_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_23ea2_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_23ea2_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_23ea2_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_23ea2_row8_col0" class="data row8 col0" >Normalize</td>
#       <td id="T_23ea2_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_23ea2_row9_col0" class="data row9 col0" >Normalize method</td>
#       <td id="T_23ea2_row9_col1" class="data row9 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_23ea2_row10_col0" class="data row10 col0" >CPU Jobs</td>
#       <td id="T_23ea2_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_23ea2_row11_col0" class="data row11 col0" >Use GPU</td>
#       <td id="T_23ea2_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_23ea2_row12_col0" class="data row12 col0" >Log Experiment</td>
#       <td id="T_23ea2_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_23ea2_row13_col0" class="data row13 col0" >Experiment Name</td>
#       <td id="T_23ea2_row13_col1" class="data row13 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_23ea2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_23ea2_row14_col0" class="data row14 col0" >USI</td>
#       <td id="T_23ea2_row14_col1" class="data row14 col1" >a5e0</td>
#     </tr>
#   </tbody>
# </table>
